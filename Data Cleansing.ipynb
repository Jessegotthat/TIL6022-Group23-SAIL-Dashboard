# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'C:\Users\muham\OneDrive - Delft University of Technology\1. First Term\TIL Python Programming\Group 23 Final Project\Python Programming\Haris Branch\SAIL2025_LVMA_data_3min_20August-25August2025_flow.csv')
print(df)
# Out:
#                       timestamp  CMSA-GAKH-01_0  CMSA-GAKH-01_180  \
# 0     2025-08-20 00:00:00+02:00              15                 4
# 1     2025-08-20 00:03:00+02:00               1                 3
# 2     2025-08-20 00:06:00+02:00               5                 4
# 3     2025-08-20 00:09:00+02:00               4                 4
# 4     2025-08-20 00:12:00+02:00               4                11
# ...                         ...             ...               ...
# 2395  2025-08-24 23:45:00+02:00              11                 9
# 2396  2025-08-24 23:48:00+02:00               2                 1
# 2397  2025-08-24 23:51:00+02:00              10                 2
# 2398  2025-08-24 23:54:00+02:00               3                 1
# 2399  2025-08-24 23:57:00+02:00               6                 1
#
#       CMSA-GAWW-11_120  CMSA-GAWW-11_300  CMSA-GAWW-12_115  CMSA-GAWW-12_295  \
# 0                   29                33                44                28
# ...

# %%
df.dropna()
# Out:
#                       timestamp  CMSA-GAKH-01_0  CMSA-GAKH-01_180  \
# 0     2025-08-20 00:00:00+02:00              15                 4
# 1     2025-08-20 00:03:00+02:00               1                 3
# 2     2025-08-20 00:06:00+02:00               5                 4
# 3     2025-08-20 00:09:00+02:00               4                 4
# 4     2025-08-20 00:12:00+02:00               4                11
# ...                         ...             ...               ...
# 2395  2025-08-24 23:45:00+02:00              11                 9
# 2396  2025-08-24 23:48:00+02:00               2                 1
# 2397  2025-08-24 23:51:00+02:00              10                 2
# 2398  2025-08-24 23:54:00+02:00               3                 1
# 2399  2025-08-24 23:57:00+02:00               6                 1
#
#       CMSA-GAWW-11_120  CMSA-GAWW-11_300  CMSA-GAWW-12_115  CMSA-GAWW-12_295  \
# 0                   29                33                44                28
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['date'] = df['timestamp'].dt.date
df['hour'] = df['timestamp'].dt.hour

# %%
df['timestamp'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns = df.columns.str.lower().str.replace('-', '_')
df.dropna()
# Out:
#                      timestamp  cmsa_gakh_01_0  cmsa_gakh_01_180  \
# 0    2025-08-20 00:00:00+02:00              15                 4
# 1    2025-08-20 00:03:00+02:00               1                 3
# 2    2025-08-20 00:06:00+02:00               5                 4
# 3    2025-08-20 00:09:00+02:00               4                 4
# 4    2025-08-20 00:12:00+02:00               4                11
# ...                        ...             ...               ...
# 2395 2025-08-24 23:45:00+02:00              11                 9
# 2396 2025-08-24 23:48:00+02:00               2                 1
# 2397 2025-08-24 23:51:00+02:00              10                 2
# 2398 2025-08-24 23:54:00+02:00               3                 1
# 2399 2025-08-24 23:57:00+02:00               6                 1
#
#       cmsa_gaww_11_120  cmsa_gaww_11_300  cmsa_gaww_12_115  cmsa_gaww_12_295  \
# 0                   29                33                44                28
# ...

# %%
df.describe().T
# Out:
#                    count       mean        std   min    25%   50%     75%  \
# cmsa_gakh_01_0    2400.0  57.513750  69.204386   0.0   3.00  17.0  110.25
# cmsa_gakh_01_180  2400.0  49.180000  58.768898   0.0   2.00  15.0   95.00
# cmsa_gaww_11_120  2400.0  37.840417  36.631952   0.0   6.00  30.0   59.00
# cmsa_gaww_11_300  2400.0  37.500417  33.478431   0.0   6.00  32.0   61.00
# cmsa_gaww_12_115  2400.0  39.021250  34.266092   0.0   7.00  32.0   62.00
# ...                  ...        ...        ...   ...    ...   ...     ...
# minute            2400.0  28.500000  17.302449   0.0  14.25  28.5   42.75
# day               2400.0  22.000000   1.414508  20.0  21.00  22.0   23.00
# month             2400.0   8.000000   0.000000   8.0   8.00   8.0    8.00
# weekday           2400.0   4.000000   1.414508   2.0   3.00   4.0    5.00
# is_weekend        2400.0   0.400000   0.490000   0.0   0.00   0.0    1.00
#
#                     max
# cmsa_gakh_01_0    266.0
# cmsa_gakh_01_180  257.0
# ...

# %%
df.plot(x='timestamp', y='cmsa_gaww_11_120', figsize=(10,5))
# Out:
# <Axes: xlabel='timestamp'>

# %%
df[['cmsa_gaww_11_120', 'cmsa_gaww_11_300']].plot.box(figsize=(6,4))
# Out:
# <Axes: >

# %%
df.to_csv('SAIL2025_LVMA_cleaned.csv', index=False)
