# %%
import pandas as pd

csv_path = r"C:\Users\muham\github-classroom\TIL6022-Group23-SAIL-Dashboard\Vesselposition_data_20-24Aug2025.csv"
parquet_path = r"C:\Users\muham\github-classroom\TIL6022-Group23-SAIL-Dashboard\Vesselposition_data_20-24Aug2025.parquet"

# Only read needed columns
df = pd.read_csv(csv_path, usecols=["id", "upload-timestamp"], low_memory=False)
df.to_parquet(parquet_path, index=False)
